# %% [markdown]
# # Python Tutorial Assignment #2
# ## This assignment is just to get you comfortable with string,  lists and functions.
#
# You do not have to submit these to anyone, but if you complete them on your own, it will help solidify your understanding of the fundamentals we have covered.
#
# ### Please save the file with a different name now! (such as assignment_1_DS or whatever your initials may be)
# If you do not do this, your work may be overwritten the next time we pull down a new lecture.
#
# In future assignement, I will try to make these assignments related to the work we do as best as possible, but I am open to suggestions as to how to do this better.
#
# ___

# %% [markdown]
# ### I. B. Dictionary Example
#
# The code below loads a dictionary of PMBUs and EBUs from the unbilled backlog report.
#
# The keys are the PMBUs (product mangement BU?) and the EBU is the enterprise business unit.
#
# NOTE: We are using pickle here, which we will get to later.

# %%
import pickle

with open( "../data/bu_dict.p", "rb" ) as f:
    bu_dict = pickle.load(f)

# %%
bu_dict
# Out:
# {'Platform and Other': 'Shared Marketing Cloud',
#  'Magento': 'Commerce',
#  'Design': 'Creative',
#  'Adobe Sign': 'Document Cloud',
#  'Marketo': 'Customer Journey Management',
#  'Stock Photography': 'Creative',
#  'Adobe Campaign': 'Customer Journey Management',
#  'Forms': 'Content',
#  'Adobe Analytics': 'Data & Insights',
#  'Audience Manager': 'Data & Insights',
#  'Adobe Target': 'Data & Insights',
#  'Assets': 'Content',
#  'Sites': 'Content',
#  'Acrobat Desk': 'Document Cloud',
#  'CCE + Stock': 'Creative',
#  'DCE': 'Document Cloud',
#  'Print Scan': 'Print & Publishing',
#  'ColdFusion': 'Print & Publishing',
#  'Real Time CDP (IS)': 'Data & Insights',
#  'Journeys': 'Customer Journey Management',
#  'Adobe Exp Platform': 'Data & Insights',
#  'Customer Journey Analytics': 'Data & Insights',
#  'Adobe Video Solutions': 'Adobe  Video Solutions',
#  'AEM Other': 'AEM Other'}

# %% [markdown]
# ### 1. Create a list of the unique PMBUs (the keys) from the dictionary.
#
# NOTE: Since the PMBUs are the dictionary keys, they are already unique. Remember dictionary keys have to be different or python will overwrite the key with the last value entered for the same key. (That was terribly explained, but see the example above where we merged a dictionary.)

# %% [markdown]
# ## 2. Create a list of the unique EBUs (values) from the dictionary.

# %% [markdown]
# ## 3. Create a list of PMBUs in each EBU using a function or multiple functions.
# So we are essentially flipping the key, value pairs such that the EBU will be the key and the value will be a list of the PMBUs in each EBU.

# %% [markdown]
# ### California Covid Statistics
#
# The 'CA_covid_data.json' file contains historical data about the number of Covid cased in California.
#
# json data is basiscally a big dictionary or a list of dictionaries. To import this into python, execute the two lines below.

# %%
import json

with open('../data/CA_covid_data.json') as json_file:
    covid_data = json.load(json_file)

# %% [markdown]
# ## 1. What datatype is covid_dict?

# %% [markdown]
# ## 2. Create a list of the dates contained in the data and name it date_list.
#
# What is the first date? What is the last date?

# %%
covid_data
# Out:
# [{'date': 20200806,
#   'state': 'CA',
#   'positive': 529980,
#   'negative': 7970483,
#   'pending': None,
#   'hospitalizedCurrently': 7485,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2026,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '8/6/2020 00:00',
#   'dateModified': '2020-08-06T00:00:00Z',
#   'checkTimeEt': '08/05 20:00',
#   'death': 9869,
#   'hospitalized': None,
#   'dateChecked': '2020-08-06T00:00:00Z',
#   'totalTestsViral': 8500463,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 529980,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 5258,
#   'negativeIncrease': 85805,
#   'total': 8500463,
#   'totalTestResults': 8500463,
#   'totalTestResultsIncrease': 91063,
#   'posNeg': 8500463,
#   'deathIncrease': 166,
#   'hospitalizedIncrease': 0,
#   'hash': '04d0f37534059d04347fd2c84c1183d80fe86371',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200805,
#   'state': 'CA',
#   'positive': 524722,
#   'negative': 7884678,
#   'pending': None,
#   'hospitalizedCurrently': 7552,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2005,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '8/5/2020 00:00',
#   'dateModified': '2020-08-05T00:00:00Z',
#   'checkTimeEt': '08/04 20:00',
#   'death': 9703,
#   'hospitalized': None,
#   'dateChecked': '2020-08-05T00:00:00Z',
#   'totalTestsViral': 8409400,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 524722,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 5295,
#   'negativeIncrease': 98392,
#   'total': 8409400,
#   'totalTestResults': 8409400,
#   'totalTestResultsIncrease': 103687,
#   'posNeg': 8409400,
#   'deathIncrease': 202,
#   'hospitalizedIncrease': 0,
#   'hash': 'c877f9c8b267330bc105adeffdf3dce664b3ba94',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200804,
#   'state': 'CA',
#   'positive': 519427,
#   'negative': 7786286,
#   'pending': None,
#   'hospitalizedCurrently': 7630,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2082,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '8/4/2020 00:00',
#   'dateModified': '2020-08-04T00:00:00Z',
#   'checkTimeEt': '08/03 20:00',
#   'death': 9501,
#   'hospitalized': None,
#   'dateChecked': '2020-08-04T00:00:00Z',
#   'totalTestsViral': 8305713,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 519427,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 4526,
#   'negativeIncrease': 116491,
#   'total': 8305713,
#   'totalTestResults': 8305713,
#   'totalTestResultsIncrease': 121017,
#   'posNeg': 8305713,
#   'deathIncrease': 113,
#   'hospitalizedIncrease': 0,
#   'hash': '90e3e08ccbd077a1dd09f6322366feedef7d2356',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200803,
#   'state': 'CA',
#   'positive': 514901,
#   'negative': 7669795,
#   'pending': None,
#   'hospitalizedCurrently': 7629,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2069,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '8/3/2020 00:00',
#   'dateModified': '2020-08-03T00:00:00Z',
#   'checkTimeEt': '08/02 20:00',
#   'death': 9388,
#   'hospitalized': None,
#   'dateChecked': '2020-08-03T00:00:00Z',
#   'totalTestsViral': 8184696,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 514901,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 5739,
#   'negativeIncrease': 142982,
#   'total': 8184696,
#   'totalTestResults': 8184696,
#   'totalTestResultsIncrease': 148721,
#   'posNeg': 8184696,
#   'deathIncrease': 32,
#   'hospitalizedIncrease': 0,
#   'hash': '3e13c19ce424ee3a196c2af8c24fa9df6cedf226',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200802,
#   'state': 'CA',
#   'positive': 509162,
#   'negative': 7526813,
#   'pending': None,
#   'hospitalizedCurrently': 7761,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2119,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '8/2/2020 00:00',
#   'dateModified': '2020-08-02T00:00:00Z',
#   'checkTimeEt': '08/01 20:00',
#   'death': 9356,
#   'hospitalized': None,
#   'dateChecked': '2020-08-02T00:00:00Z',
#   'totalTestsViral': 8035975,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 509162,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 9032,
#   'negativeIncrease': 140356,
#   'total': 8035975,
#   'totalTestResults': 8035975,
#   'totalTestResultsIncrease': 149388,
#   'posNeg': 8035975,
#   'deathIncrease': 132,
#   'hospitalizedIncrease': 0,
#   'hash': 'acaee9f7ca22b9c2c31866d7b2477e601fef5c3a',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200801,
#   'state': 'CA',
#   'positive': 500130,
#   'negative': 7386457,
#   'pending': None,
#   'hospitalizedCurrently': 7754,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2120,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/31/2020 00:00',
#   'dateModified': '2020-07-31T00:00:00Z',
#   'checkTimeEt': '07/30 20:00',
#   'death': 9224,
#   'hospitalized': None,
#   'dateChecked': '2020-07-31T00:00:00Z',
#   'totalTestsViral': 7886587,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 500130,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 6542,
#   'negativeIncrease': 69004,
#   'total': 7886587,
#   'totalTestResults': 7886587,
#   'totalTestResultsIncrease': 75546,
#   'posNeg': 7886587,
#   'deathIncrease': 219,
#   'hospitalizedIncrease': 0,
#   'hash': '7d0897f15a2eea9c1f439002d4e9cb86eaba030f',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200731,
#   'state': 'CA',
#   'positive': 493588,
#   'negative': 7317453,
#   'pending': None,
#   'hospitalizedCurrently': 7999,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2163,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/31/2020 00:00',
#   'dateModified': '2020-07-31T00:00:00Z',
#   'checkTimeEt': '07/30 20:00',
#   'death': 9005,
#   'hospitalized': None,
#   'dateChecked': '2020-07-31T00:00:00Z',
#   'totalTestsViral': 7811041,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 493588,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 8086,
#   'negativeIncrease': 169115,
#   'total': 7811041,
#   'totalTestResults': 7811041,
#   'totalTestResultsIncrease': 177201,
#   'posNeg': 7811041,
#   'deathIncrease': 96,
#   'hospitalizedIncrease': 0,
#   'hash': '01334802bc96449522bb9a789767abc759b9c877',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200730,
#   'state': 'CA',
#   'positive': 485502,
#   'negative': 7148338,
#   'pending': None,
#   'hospitalizedCurrently': 8198,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2220,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/30/2020 00:00',
#   'dateModified': '2020-07-30T00:00:00Z',
#   'checkTimeEt': '07/29 20:00',
#   'death': 8909,
#   'hospitalized': None,
#   'dateChecked': '2020-07-30T00:00:00Z',
#   'totalTestsViral': 7633840,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 485502,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 10197,
#   'negativeIncrease': 106177,
#   'total': 7633840,
#   'totalTestResults': 7633840,
#   'totalTestResultsIncrease': 116374,
#   'posNeg': 7633840,
#   'deathIncrease': 194,
#   'hospitalizedIncrease': 0,
#   'hash': '2390e7743f2eb82e34881a08d0806a179febc29f',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200729,
#   'state': 'CA',
#   'positive': 475305,
#   'negative': 7042161,
#   'pending': None,
#   'hospitalizedCurrently': 8439,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2209,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/29/2020 00:00',
#   'dateModified': '2020-07-29T00:00:00Z',
#   'checkTimeEt': '07/28 20:00',
#   'death': 8715,
#   'hospitalized': None,
#   'dateChecked': '2020-07-29T00:00:00Z',
#   'totalTestsViral': 7517466,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 475305,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 8755,
#   'negativeIncrease': 90845,
#   'total': 7517466,
#   'totalTestResults': 7517466,
#   'totalTestResultsIncrease': 99600,
#   'posNeg': 7517466,
#   'deathIncrease': 197,
#   'hospitalizedIncrease': 0,
#   'hash': '7f4678b42a7b927423b1a4e5fb8f2c5db240c043',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200728,
#   'state': 'CA',
#   'positive': 466550,
#   'negative': 6951316,
#   'pending': None,
#   'hospitalizedCurrently': 8317,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2198,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/28/2020 00:00',
#   'dateModified': '2020-07-28T00:00:00Z',
#   'checkTimeEt': '07/27 20:00',
#   'death': 8518,
#   'hospitalized': None,
#   'dateChecked': '2020-07-28T00:00:00Z',
#   'totalTestsViral': 7417866,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 466550,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 6000,
#   'negativeIncrease': 115288,
#   'total': 7417866,
#   'totalTestResults': 7417866,
#   'totalTestResultsIncrease': 121288,
#   'posNeg': 7417866,
#   'deathIncrease': 73,
#   'hospitalizedIncrease': 0,
#   'hash': 'e9a53bd0b34d58e584d33393a1acc8673d8e9b05',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200727,
#   'state': 'CA',
#   'positive': 460550,
#   'negative': 6836028,
#   'pending': None,
#   'hospitalizedCurrently': 8820,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2284,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/27/2020 00:00',
#   'dateModified': '2020-07-27T00:00:00Z',
#   'checkTimeEt': '07/26 20:00',
#   'death': 8445,
#   'hospitalized': None,
#   'dateChecked': '2020-07-27T00:00:00Z',
#   'totalTestsViral': 7296578,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 460550,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 6891,
#   'negativeIncrease': 121548,
#   'total': 7296578,
#   'totalTestResults': 7296578,
#   'totalTestResultsIncrease': 128439,
#   'posNeg': 7296578,
#   'deathIncrease': 29,
#   'hospitalizedIncrease': 0,
#   'hash': 'b8931466ea5a52fb64e1683aec4d3e4c412f1f7e',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200726,
#   'state': 'CA',
#   'positive': 453659,
#   'negative': 6714480,
#   'pending': None,
#   'hospitalizedCurrently': 8820,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2284,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/26/2020 00:00',
#   'dateModified': '2020-07-26T00:00:00Z',
#   'checkTimeEt': '07/25 20:00',
#   'death': 8416,
#   'hospitalized': None,
#   'dateChecked': '2020-07-26T00:00:00Z',
#   'totalTestsViral': 7168139,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 453659,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 8259,
#   'negativeIncrease': 112525,
#   'total': 7168139,
#   'totalTestResults': 7168139,
#   'totalTestResultsIncrease': 120784,
#   'posNeg': 7168139,
#   'deathIncrease': 79,
#   'hospitalizedIncrease': 0,
#   'hash': '2de2a3bb3e4a36be3abf85f9636ed9b58cbf4df4',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'CA',
#   'positive': 445400,
#   'negative': 6601955,
#   'pending': None,
#   'hospitalizedCurrently': 8820,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2284,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/25/2020 00:00',
#   'dateModified': '2020-07-25T00:00:00Z',
#   'checkTimeEt': '07/24 20:00',
#   'death': 8337,
#   'hospitalized': None,
#   'dateChecked': '2020-07-25T00:00:00Z',
#   'totalTestsViral': 7047355,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 445400,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 10066,
#   'negativeIncrease': 121413,
#   'total': 7047355,
#   'totalTestResults': 7047355,
#   'totalTestResultsIncrease': 131479,
#   'posNeg': 7047355,
#   'deathIncrease': 151,
#   'hospitalizedIncrease': 0,
#   'hash': '1c3c5e5d7d8a78e1027e606bc3fe62b193ea414e',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200724,
#   'state': 'CA',
#   'positive': 435334,
#   'negative': 6480542,
#   'pending': None,
#   'hospitalizedCurrently': 8820,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2284,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/24/2020 00:00',
#   'dateModified': '2020-07-24T00:00:00Z',
#   'checkTimeEt': '07/23 20:00',
#   'death': 8186,
#   'hospitalized': None,
#   'dateChecked': '2020-07-24T00:00:00Z',
#   'totalTestsViral': 6915876,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 435334,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 9718,
#   'negativeIncrease': 127854,
#   'total': 6915876,
#   'totalTestResults': 6915876,
#   'totalTestResultsIncrease': 137572,
#   'posNeg': 6915876,
#   'deathIncrease': 159,
#   'hospitalizedIncrease': 0,
#   'hash': '00c84b97e9b372b477ce7feeb37b6a9b5f3f1be4',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200723,
#   'state': 'CA',
#   'positive': 425616,
#   'negative': 6352688,
#   'pending': None,
#   'hospitalizedCurrently': 8820,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2284,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/23/2020 00:00',
#   'dateModified': '2020-07-23T00:00:00Z',
#   'checkTimeEt': '07/22 20:00',
#   'death': 8027,
#   'hospitalized': None,
#   'dateChecked': '2020-07-23T00:00:00Z',
#   'totalTestsViral': 6778304,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 425616,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 12040,
#   'negativeIncrease': 101845,
#   'total': 6778304,
#   'totalTestResults': 6778304,
#   'totalTestResultsIncrease': 113885,
#   'posNeg': 6778304,
#   'deathIncrease': 157,
#   'hospitalizedIncrease': 0,
#   'hash': '682fff550ee553f1a82d03c82deaf07c520373df',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200722,
#   'state': 'CA',
#   'positive': 413576,
#   'negative': 6250843,
#   'pending': None,
#   'hospitalizedCurrently': 8820,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2284,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/22/2020 00:00',
#   'dateModified': '2020-07-22T00:00:00Z',
#   'checkTimeEt': '07/21 20:00',
#   'death': 7870,
#   'hospitalized': None,
#   'dateChecked': '2020-07-22T00:00:00Z',
#   'totalTestsViral': 6664419,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 413576,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 12807,
#   'negativeIncrease': 114680,
#   'total': 6664419,
#   'totalTestResults': 6664419,
#   'totalTestResultsIncrease': 127487,
#   'posNeg': 6664419,
#   'deathIncrease': 115,
#   'hospitalizedIncrease': 0,
#   'hash': '9e07fb0a4bb5e4616284aebc1d201ad7133c049a',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200721,
#   'state': 'CA',
#   'positive': 400769,
#   'negative': 6136163,
#   'pending': None,
#   'hospitalizedCurrently': 8681,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2226,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/21/2020 00:00',
#   'dateModified': '2020-07-21T00:00:00Z',
#   'checkTimeEt': '07/20 20:00',
#   'death': 7755,
#   'hospitalized': None,
#   'dateChecked': '2020-07-21T00:00:00Z',
#   'totalTestsViral': 6536932,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 400769,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 9231,
#   'negativeIncrease': 113380,
#   'total': 6536932,
#   'totalTestResults': 6536932,
#   'totalTestResultsIncrease': 122611,
#   'posNeg': 6536932,
#   'deathIncrease': 61,
#   'hospitalizedIncrease': 0,
#   'hash': 'c5f9f05c2b366e3f77d195585f936816c1359e2f',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200720,
#   'state': 'CA',
#   'positive': 391538,
#   'negative': 6022783,
#   'pending': None,
#   'hospitalizedCurrently': 8419,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2157,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/20/2020 00:00',
#   'dateModified': '2020-07-20T00:00:00Z',
#   'checkTimeEt': '07/19 20:00',
#   'death': 7694,
#   'hospitalized': None,
#   'dateChecked': '2020-07-20T00:00:00Z',
#   'totalTestsViral': 6414321,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 391538,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 6846,
#   'negativeIncrease': 120623,
#   'total': 6414321,
#   'totalTestResults': 6414321,
#   'totalTestResultsIncrease': 127469,
#   'posNeg': 6414321,
#   'deathIncrease': 9,
#   'hospitalizedIncrease': 0,
#   'hash': 'cd6be133298352ecb8fde204fba59b39e15b0f80',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200719,
#   'state': 'CA',
#   'positive': 384692,
#   'negative': 5902160,
#   'pending': None,
#   'hospitalizedCurrently': 8398,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2107,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/19/2020 00:00',
#   'dateModified': '2020-07-19T00:00:00Z',
#   'checkTimeEt': '07/18 20:00',
#   'death': 7685,
#   'hospitalized': None,
#   'dateChecked': '2020-07-19T00:00:00Z',
#   'totalTestsViral': 6286852,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 384692,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 9329,
#   'negativeIncrease': 110305,
#   'total': 6286852,
#   'totalTestResults': 6286852,
#   'totalTestResultsIncrease': 119634,
#   'posNeg': 6286852,
#   'deathIncrease': 90,
#   'hospitalizedIncrease': 0,
#   'hash': '679f115e835cebf3d0107f1d0394d362db540399',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200718,
#   'state': 'CA',
#   'positive': 375363,
#   'negative': 5791855,
#   'pending': None,
#   'hospitalizedCurrently': 8502,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2125,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/18/2020 00:00',
#   'dateModified': '2020-07-18T00:00:00Z',
#   'checkTimeEt': '07/17 20:00',
#   'death': 7595,
#   'hospitalized': None,
#   'dateChecked': '2020-07-18T00:00:00Z',
#   'totalTestsViral': 6167218,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 375363,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 9199,
#   'negativeIncrease': 113920,
#   'total': 6167218,
#   'totalTestResults': 6167218,
#   'totalTestResultsIncrease': 123119,
#   'posNeg': 6167218,
#   'deathIncrease': 120,
#   'hospitalizedIncrease': 0,
#   'hash': 'c7ccfc309a1cc4b49de9e979a64e516a5ae76e3e',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200717,
#   'state': 'CA',
#   'positive': 366164,
#   'negative': 5677935,
#   'pending': None,
#   'hospitalizedCurrently': 8450,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2153,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/17/2020 00:00',
#   'dateModified': '2020-07-17T00:00:00Z',
#   'checkTimeEt': '07/16 20:00',
#   'death': 7475,
#   'hospitalized': None,
#   'dateChecked': '2020-07-17T00:00:00Z',
#   'totalTestsViral': 6044099,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 366164,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 9986,
#   'negativeIncrease': 118605,
#   'total': 6044099,
#   'totalTestResults': 6044099,
#   'totalTestResultsIncrease': 128591,
#   'posNeg': 6044099,
#   'deathIncrease': 130,
#   'hospitalizedIncrease': 0,
#   'hash': 'fc67eb477c9c738f23fb314ab228a3e376877d8a',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200716,
#   'state': 'CA',
#   'positive': 356178,
#   'negative': 5559330,
#   'pending': None,
#   'hospitalizedCurrently': 8363,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2120,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/16/2020 00:00',
#   'dateModified': '2020-07-16T00:00:00Z',
#   'checkTimeEt': '07/15 20:00',
#   'death': 7345,
#   'hospitalized': None,
#   'dateChecked': '2020-07-16T00:00:00Z',
#   'totalTestsViral': 5915508,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 356178,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 8544,
#   'negativeIncrease': 113688,
#   'total': 5915508,
#   'totalTestResults': 5915508,
#   'totalTestResultsIncrease': 122232,
#   'posNeg': 5915508,
#   'deathIncrease': 118,
#   'hospitalizedIncrease': 0,
#   'hash': '5036fe722b685c1518e7feb4bce0c3f170c8d10e',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200715,
#   'state': 'CA',
#   'positive': 347634,
#   'negative': 5445642,
#   'pending': None,
#   'hospitalizedCurrently': 8353,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2110,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/15/2020 00:00',
#   'dateModified': '2020-07-15T00:00:00Z',
#   'checkTimeEt': '07/14 20:00',
#   'death': 7227,
#   'hospitalized': None,
#   'dateChecked': '2020-07-15T00:00:00Z',
#   'totalTestsViral': 5793276,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 347634,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 11126,
#   'negativeIncrease': 107195,
#   'total': 5793276,
#   'totalTestResults': 5793276,
#   'totalTestResultsIncrease': 118321,
#   'posNeg': 5793276,
#   'deathIncrease': 140,
#   'hospitalizedIncrease': 0,
#   'hash': '3284751051687e53d0dfa857b8524346100ec888',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200714,
#   'state': 'CA',
#   'positive': 336508,
#   'negative': 5338447,
#   'pending': None,
#   'hospitalizedCurrently': 8145,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2083,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/14/2020 00:00',
#   'dateModified': '2020-07-14T00:00:00Z',
#   'checkTimeEt': '07/13 20:00',
#   'death': 7087,
#   'hospitalized': None,
#   'dateChecked': '2020-07-14T00:00:00Z',
#   'totalTestsViral': 5674955,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 336508,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 7346,
#   'negativeIncrease': 123244,
#   'total': 5674955,
#   'totalTestResults': 5674955,
#   'totalTestResultsIncrease': 130590,
#   'posNeg': 5674955,
#   'deathIncrease': 47,
#   'hospitalizedIncrease': 0,
#   'hash': 'd823ee4c4b51f7f10f134b0f71e7fdb61ec5b3fa',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200713,
#   'state': 'CA',
#   'positive': 329162,
#   'negative': 5215203,
#   'pending': None,
#   'hospitalizedCurrently': 7895,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2021,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/13/2020 00:00',
#   'dateModified': '2020-07-13T00:00:00Z',
#   'checkTimeEt': '07/12 20:00',
#   'death': 7040,
#   'hospitalized': None,
#   'dateChecked': '2020-07-13T00:00:00Z',
#   'totalTestsViral': 5544365,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 329162,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 8358,
#   'negativeIncrease': 129408,
#   'total': 5544365,
#   'totalTestResults': 5544365,
#   'totalTestResultsIncrease': 137766,
#   'posNeg': 5544365,
#   'deathIncrease': 23,
#   'hospitalizedIncrease': 0,
#   'hash': 'c0dfd793447c8645bea4f9658759aa42a854b63a',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200712,
#   'state': 'CA',
#   'positive': 320804,
#   'negative': 5085795,
#   'pending': None,
#   'hospitalizedCurrently': 7854,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2020,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/12/2020 00:00',
#   'dateModified': '2020-07-12T00:00:00Z',
#   'checkTimeEt': '07/11 20:00',
#   'death': 7017,
#   'hospitalized': None,
#   'dateChecked': '2020-07-12T00:00:00Z',
#   'totalTestsViral': 5406599,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 320804,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 8460,
#   'negativeIncrease': 122444,
#   'total': 5406599,
#   'totalTestResults': 5406599,
#   'totalTestResultsIncrease': 130904,
#   'posNeg': 5406599,
#   'deathIncrease': 72,
#   'hospitalizedIncrease': 0,
#   'hash': '7f0a7ef4ab2864dfe91670dbd8db994e291b0d65',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200711,
#   'state': 'CA',
#   'positive': 312344,
#   'negative': 4963351,
#   'pending': None,
#   'hospitalizedCurrently': 7904,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2021,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/11/2020 00:00',
#   'dateModified': '2020-07-11T00:00:00Z',
#   'checkTimeEt': '07/10 20:00',
#   'death': 6945,
#   'hospitalized': None,
#   'dateChecked': '2020-07-11T00:00:00Z',
#   'totalTestsViral': 5275695,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 312344,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 8047,
#   'negativeIncrease': 91911,
#   'total': 5275695,
#   'totalTestResults': 5275695,
#   'totalTestResultsIncrease': 99958,
#   'posNeg': 5275695,
#   'deathIncrease': 94,
#   'hospitalizedIncrease': 0,
#   'hash': 'be5241e551c19c99f87be6429800baa947d24cf6',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200710,
#   'state': 'CA',
#   'positive': 304297,
#   'negative': 4871440,
#   'pending': None,
#   'hospitalizedCurrently': 7896,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2005,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/10/2020 00:00',
#   'dateModified': '2020-07-10T00:00:00Z',
#   'checkTimeEt': '07/09 20:00',
#   'death': 6851,
#   'hospitalized': None,
#   'dateChecked': '2020-07-10T00:00:00Z',
#   'totalTestsViral': 5175737,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 304297,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 7798,
#   'negativeIncrease': 89505,
#   'total': 5175737,
#   'totalTestResults': 5175737,
#   'totalTestResultsIncrease': 97303,
#   'posNeg': 5175737,
#   'deathIncrease': 140,
#   'hospitalizedIncrease': 0,
#   'hash': '7ed43229bfbe0897133758f20cc575329e2daa9e',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200709,
#   'state': 'CA',
#   'positive': 296499,
#   'negative': 4781935,
#   'pending': None,
#   'hospitalizedCurrently': 7821,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1957,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/9/2020 00:00',
#   'dateModified': '2020-07-09T00:00:00Z',
#   'checkTimeEt': '07/08 20:00',
#   'death': 6711,
#   'hospitalized': None,
#   'dateChecked': '2020-07-09T00:00:00Z',
#   'totalTestsViral': 5078434,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 296499,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 7031,
#   'negativeIncrease': 75228,
#   'total': 5078434,
#   'totalTestResults': 5078434,
#   'totalTestResultsIncrease': 82259,
#   'posNeg': 5078434,
#   'deathIncrease': 149,
#   'hospitalizedIncrease': 0,
#   'hash': '2f769b0e0429da6b96c7d0480d6d59b1b1e0781b',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'CA',
#   'positive': 289468,
#   'negative': 4706707,
#   'pending': None,
#   'hospitalizedCurrently': 7705,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1976,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/8/2020 00:00',
#   'dateModified': '2020-07-08T00:00:00Z',
#   'checkTimeEt': '07/07 20:00',
#   'death': 6562,
#   'hospitalized': None,
#   'dateChecked': '2020-07-08T00:00:00Z',
#   'totalTestsViral': 4996175,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 289468,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 11694,
#   'negativeIncrease': 88111,
#   'total': 4996175,
#   'totalTestResults': 4996175,
#   'totalTestResultsIncrease': 99805,
#   'posNeg': 4996175,
#   'deathIncrease': 114,
#   'hospitalizedIncrease': 0,
#   'hash': '3537046bf4188b187fc618317db06c2d9f345e87',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200707,
#   'state': 'CA',
#   'positive': 277774,
#   'negative': 4618596,
#   'pending': None,
#   'hospitalizedCurrently': 7499,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1984,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/7/2020 00:00',
#   'dateModified': '2020-07-07T00:00:00Z',
#   'checkTimeEt': '07/06 20:00',
#   'death': 6448,
#   'hospitalized': None,
#   'dateChecked': '2020-07-07T00:00:00Z',
#   'totalTestsViral': 4896370,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 277774,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 6090,
#   'negativeIncrease': 96927,
#   'total': 4896370,
#   'totalTestResults': 4896370,
#   'totalTestResultsIncrease': 103017,
#   'posNeg': 4896370,
#   'deathIncrease': 111,
#   'hospitalizedIncrease': 0,
#   'hash': 'bda260afa5a8b8762b2c464b5619cecb3c5358c6',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200706,
#   'state': 'CA',
#   'positive': 271684,
#   'negative': 4521669,
#   'pending': None,
#   'hospitalizedCurrently': 7278,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1937,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/6/2020 00:00',
#   'dateModified': '2020-07-06T00:00:00Z',
#   'checkTimeEt': '07/05 20:00',
#   'death': 6337,
#   'hospitalized': None,
#   'dateChecked': '2020-07-06T00:00:00Z',
#   'totalTestsViral': 4793353,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 271684,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 5699,
#   'negativeIncrease': 107516,
#   'total': 4793353,
#   'totalTestResults': 4793353,
#   'totalTestResultsIncrease': 113215,
#   'posNeg': 4793353,
#   'deathIncrease': 6,
#   'hospitalizedIncrease': 0,
#   'hash': 'c954e75ad41457f13666ee43673ca235c36136ab',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200705,
#   'state': 'CA',
#   'positive': 265985,
#   'negative': 4414153,
#   'pending': None,
#   'hospitalizedCurrently': 7149,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1907,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/5/2020 00:00',
#   'dateModified': '2020-07-05T00:00:00Z',
#   'checkTimeEt': '07/04 20:00',
#   'death': 6331,
#   'hospitalized': None,
#   'dateChecked': '2020-07-05T00:00:00Z',
#   'totalTestsViral': 4680138,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 265985,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 8597,
#   'negativeIncrease': 118510,
#   'total': 4680138,
#   'totalTestResults': 4680138,
#   'totalTestResultsIncrease': 127107,
#   'posNeg': 4680138,
#   'deathIncrease': 18,
#   'hospitalizedIncrease': 0,
#   'hash': 'e58c6bb8c8c40f33280485e9929bedfdb1c48e4d',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200704,
#   'state': 'CA',
#   'positive': 257388,
#   'negative': 4295643,
#   'pending': None,
#   'hospitalizedCurrently': 7092,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1888,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/4/2020 00:00',
#   'dateModified': '2020-07-04T00:00:00Z',
#   'checkTimeEt': '07/03 20:00',
#   'death': 6313,
#   'hospitalized': None,
#   'dateChecked': '2020-07-04T00:00:00Z',
#   'totalTestsViral': 4553031,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 257388,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 9153,
#   'negativeIncrease': 95702,
#   'total': 4553031,
#   'totalTestResults': 4553031,
#   'totalTestResultsIncrease': 104855,
#   'posNeg': 4553031,
#   'deathIncrease': 50,
#   'hospitalizedIncrease': 0,
#   'hash': '50c3899f3c1e5cfcf40b1fab75473abb27bdf182',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200703,
#   'state': 'CA',
#   'positive': 248235,
#   'negative': 4199941,
#   'pending': None,
#   'hospitalizedCurrently': 7024,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1871,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/3/2020 00:00',
#   'dateModified': '2020-07-03T00:00:00Z',
#   'checkTimeEt': '07/02 20:00',
#   'death': 6263,
#   'hospitalized': None,
#   'dateChecked': '2020-07-03T00:00:00Z',
#   'totalTestsViral': 4448176,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 248235,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 5688,
#   'negativeIncrease': 103770,
#   'total': 4448176,
#   'totalTestResults': 4448176,
#   'totalTestResultsIncrease': 109458,
#   'posNeg': 4448176,
#   'deathIncrease': 100,
#   'hospitalizedIncrease': 0,
#   'hash': '288d9cb57e0d996943af02bf914d2ab40280dee9',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200702,
#   'state': 'CA',
#   'positive': 242547,
#   'negative': 4096171,
#   'pending': None,
#   'hospitalizedCurrently': 6812,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1934,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/2/2020 00:00',
#   'dateModified': '2020-07-02T00:00:00Z',
#   'checkTimeEt': '07/01 20:00',
#   'death': 6163,
#   'hospitalized': None,
#   'dateChecked': '2020-07-02T00:00:00Z',
#   'totalTestsViral': 4338718,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 242547,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 6408,
#   'negativeIncrease': 78134,
#   'total': 4338718,
#   'totalTestResults': 4338718,
#   'totalTestResultsIncrease': 84542,
#   'posNeg': 4338718,
#   'deathIncrease': 73,
#   'hospitalizedIncrease': 0,
#   'hash': '30a53c472a365ea5018d2cb51c61e922ef5dd04f',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200701,
#   'state': 'CA',
#   'positive': 236139,
#   'negative': 4018037,
#   'pending': None,
#   'hospitalizedCurrently': 6612,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1859,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/1/2020 00:00',
#   'dateModified': '2020-07-01T00:00:00Z',
#   'checkTimeEt': '06/30 20:00',
#   'death': 6090,
#   'hospitalized': None,
#   'dateChecked': '2020-07-01T00:00:00Z',
#   'totalTestsViral': 4254176,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 236139,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 7407,
#   'negativeIncrease': 79630,
#   'total': 4254176,
#   'totalTestResults': 4254176,
#   'totalTestResultsIncrease': 87037,
#   'posNeg': 4254176,
#   'deathIncrease': 110,
#   'hospitalizedIncrease': 0,
#   'hash': 'a99f685fd7118ed94d6bdb48e670776ab0d9bd52',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200630,
#   'state': 'CA',
#   'positive': 228732,
#   'negative': 3938407,
#   'pending': None,
#   'hospitalizedCurrently': 6466,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1751,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '6/30/2020 00:00',
#   'dateModified': '2020-06-30T00:00:00Z',
#   'checkTimeEt': '06/29 20:00',
#   'death': 5980,
#   'hospitalized': None,
#   'dateChecked': '2020-06-30T00:00:00Z',
#   'totalTestsViral': 4167139,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 228732,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 9480,
#   'negativeIncrease': 95967,
#   'total': 4167139,
#   'totalTestResults': 4167139,
#   'totalTestResultsIncrease': 105447,
#   'posNeg': 4167139,
#   'deathIncrease': 44,
#   'hospitalizedIncrease': 0,
#   'hash': '7393c11e8cd90a84c9a5fd2f7d416ce81c313dc3',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200629,
#   'state': 'CA',
#   'positive': 219252,
#   'negative': 3842440,
#   'pending': None,
#   'hospitalizedCurrently': 6179,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1686,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '6/29/2020 00:00',
#   'dateModified': '2020-06-29T00:00:00Z',
#   'checkTimeEt': '06/28 20:00',
#   'death': 5936,
#   'hospitalized': None,
#   'dateChecked': '2020-06-29T00:00:00Z',
#   'totalTestsViral': 4061692,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 219252,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 8009,
#   'negativeIncrease': 97731,
#   'total': 4061692,
#   'totalTestResults': 4061692,
#   'totalTestResultsIncrease': 105740,
#   'posNeg': 4061692,
#   'deathIncrease': 31,
#   'hospitalizedIncrease': 0,
#   'hash': 'ddf39a941cea7d69094aee5a2d1fe25498cea597',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200628,
#   'state': 'CA',
#   'positive': 211243,
#   'negative': 3744709,
#   'pending': None,
#   'hospitalizedCurrently': 5956,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1602,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '6/28/2020 00:00',
#   'dateModified': '2020-06-28T00:00:00Z',
#   'checkTimeEt': '06/27 20:00',
#   'death': 5905,
#   'hospitalized': None,
#   'dateChecked': '2020-06-28T00:00:00Z',
#   'totalTestsViral': 3955952,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 211243,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 4810,
#   'negativeIncrease': 88832,
#   'total': 3955952,
#   'totalTestResults': 3955952,
#   'totalTestResultsIncrease': 93642,
#   'posNeg': 3955952,
#   'deathIncrease': 33,
#   'hospitalizedIncrease': 0,
#   'hash': '535bc444805fde24ff7c1f083bc452c4f2c4d336',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200627,
#   'state': 'CA',
#   'positive': 206433,
#   'negative': 3655877,
#   'pending': None,
#   'hospitalizedCurrently': 5790,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1562,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '6/27/2020 00:00',
#   'dateModified': '2020-06-27T00:00:00Z',
#   'checkTimeEt': '06/26 20:00',
#   'death': 5872,
#   'hospitalized': None,
#   'dateChecked': '2020-06-27T00:00:00Z',
#   'totalTestsViral': 3862310,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 206433,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 5972,
#   'negativeIncrease': 85024,
#   'total': 3862310,
#   'totalTestResults': 3862310,
#   'totalTestResultsIncrease': 90996,
#   'posNeg': 3862310,
#   'deathIncrease': 60,
#   'hospitalizedIncrease': 0,
#   'hash': '101c022c04a2829fef937a0f17c413e5a8fb334c',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200626,
#   'state': 'CA',
#   'positive': 200461,
#   'negative': 3570853,
#   'pending': None,
#   'hospitalizedCurrently': 5639,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1570,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '6/26/2020 00:00',
#   'dateModified': '2020-06-26T00:00:00Z',
#   'checkTimeEt': '06/25 20:00',
#   'death': 5812,
#   'hospitalized': None,
#   'dateChecked': '2020-06-26T00:00:00Z',
#   'totalTestsViral': 3771314,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 200461,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 4890,
#   'negativeIncrease': 72079,
#   'total': 3771314,
#   'totalTestResults': 3771314,
#   'totalTestResultsIncrease': 76969,
#   'posNeg': 3771314,
#   'deathIncrease': 79,
#   'hospitalizedIncrease': 0,
#   'hash': '2763b419337eb1c55424e3b5e9cd01e493ba5d7d',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200625,
#   'state': 'CA',
#   'positive': 195571,
#   'negative': 3498774,
#   'pending': None,
#   'hospitalizedCurrently': 5522,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 1523,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '6/25/2020 00:00',
#   'dateModified': '2020-06-25T00:00:00Z',
#   'checkTimeEt': '06/24 20:00',
#   'death': 5733,
#   'hospitalized': None,
#   'dateChecked': '2020-06-25T00:00:00Z',
#   'totalTestsViral': 3694345,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 195571,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 5349,
#   'negativeIncrease': 96097,
#   'total': 3694345,
#   'totalTestResults': 3694345,
#   'totalTestResultsIncrease': 101446,
#   'posNeg': 3694345,
#   'deathIncrease': 101,
#   'hospitalizedIncrease': 0,
#   'hash': '86ee252c23e4ecff94da6d010772f278aafa9728',
#   'commercialScore': 0,
# ...
#   'deathIncrease': 5,
#   'hospitalizedIncrease': 0,
#   'hash': '105de580eb75e5ab36f9754ca14ee13ac5980a0e',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200318,
#   'state': 'CA',
#   'positive': 611,
#   'negative': 7981,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '3/17/2020 21:00',
#   'dateModified': '2020-03-17T21:00:00Z',
#   'checkTimeEt': '03/17 17:00',
#   'death': 13,
#   'hospitalized': None,
#   'dateChecked': '2020-03-17T21:00:00Z',
#   'totalTestsViral': 8592,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 128,
#   'negativeIncrease': 0,
#   'total': 8592,
#   'totalTestResults': 8592,
#   'totalTestResultsIncrease': 128,
#   'posNeg': 8592,
#   'deathIncrease': 2,
#   'hospitalizedIncrease': 0,
#   'hash': '56e6081afce666bd9e73a1e326c772b63fef1bbc',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200317,
#   'state': 'CA',
#   'positive': 483,
#   'negative': 7981,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '3/16/2020 21:00',
#   'dateModified': '2020-03-16T21:00:00Z',
#   'checkTimeEt': '03/16 17:00',
#   'death': 11,
#   'hospitalized': None,
#   'dateChecked': '2020-03-16T21:00:00Z',
#   'totalTestsViral': 8464,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 148,
#   'negativeIncrease': 0,
#   'total': 8464,
#   'totalTestResults': 8464,
#   'totalTestResultsIncrease': 148,
#   'posNeg': 8464,
#   'deathIncrease': 5,
#   'hospitalizedIncrease': 0,
#   'hash': '9870829946c14fa6e551674bd165c3cf2eeb2982',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200316,
#   'state': 'CA',
#   'positive': 335,
#   'negative': 7981,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '3/16/2020 15:10',
#   'dateModified': '2020-03-16T15:10:00Z',
#   'checkTimeEt': '03/16 11:10',
#   'death': 6,
#   'hospitalized': None,
#   'dateChecked': '2020-03-16T15:10:00Z',
#   'totalTestsViral': 8316,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 42,
#   'negativeIncrease': 7065,
#   'total': 8316,
#   'totalTestResults': 8316,
#   'totalTestResultsIncrease': 7107,
#   'posNeg': 8316,
#   'deathIncrease': 1,
#   'hospitalizedIncrease': 0,
#   'hash': 'ab3cdadd5394f06ee64a11df18140fb52c617d01',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200315,
#   'state': 'CA',
#   'positive': 293,
#   'negative': 916,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '3/14/2020 11:00',
#   'dateModified': '2020-03-14T11:00:00Z',
#   'checkTimeEt': '03/14 07:00',
#   'death': 5,
#   'hospitalized': None,
#   'dateChecked': '2020-03-14T11:00:00Z',
#   'totalTestsViral': 1209,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 41,
#   'negativeIncrease': 0,
#   'total': 1209,
#   'totalTestResults': 1209,
#   'totalTestResultsIncrease': 41,
#   'posNeg': 1209,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': 'a54cee0d542381fcda1433ed39fc5c57d59ee684',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200314,
#   'state': 'CA',
#   'positive': 252,
#   'negative': 916,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '3/13/2020 11:00',
#   'dateModified': '2020-03-13T11:00:00Z',
#   'checkTimeEt': '03/13 07:00',
#   'death': 5,
#   'hospitalized': None,
#   'dateChecked': '2020-03-13T11:00:00Z',
#   'totalTestsViral': 1168,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 50,
#   'negativeIncrease': 0,
#   'total': 1168,
#   'totalTestResults': 1168,
#   'totalTestResultsIncrease': 50,
#   'posNeg': 1168,
#   'deathIncrease': 1,
#   'hospitalizedIncrease': 0,
#   'hash': '08910b8eb722c96a1bb6b43426090036aa0978e3',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200313,
#   'state': 'CA',
#   'positive': 202,
#   'negative': 916,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '3/12/2020 10:00',
#   'dateModified': '2020-03-12T10:00:00Z',
#   'checkTimeEt': '03/12 06:00',
#   'death': 4,
#   'hospitalized': None,
#   'dateChecked': '2020-03-12T10:00:00Z',
#   'totalTestsViral': 1118,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 0,
#   'negativeIncrease': 0,
#   'total': 1118,
#   'totalTestResults': 1118,
#   'totalTestResultsIncrease': 0,
#   'posNeg': 1118,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': 'fbb077ec6beea9ed6ae0abc83e48c0b07af55d6c',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200312,
#   'state': 'CA',
#   'positive': 202,
#   'negative': 916,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '3/12/2020 10:00',
#   'dateModified': '2020-03-12T10:00:00Z',
#   'checkTimeEt': '03/12 06:00',
#   'death': 4,
#   'hospitalized': None,
#   'dateChecked': '2020-03-12T10:00:00Z',
#   'totalTestsViral': 1118,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 45,
#   'negativeIncrease': 0,
#   'total': 1118,
#   'totalTestResults': 1118,
#   'totalTestResultsIncrease': 45,
#   'posNeg': 1118,
#   'deathIncrease': 4,
#   'hospitalizedIncrease': 0,
#   'hash': 'fb3200f4da1960dab3595c72707736126b454ca7',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200311,
#   'state': 'CA',
#   'positive': 157,
#   'negative': 916,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '',
#   'dateModified': None,
#   'checkTimeEt': None,
#   'death': None,
#   'hospitalized': None,
#   'dateChecked': None,
#   'totalTestsViral': 1073,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 24,
#   'negativeIncrease': 226,
#   'total': 1073,
#   'totalTestResults': 1073,
#   'totalTestResultsIncrease': 250,
#   'posNeg': 1073,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': 'f69529d7af78b044de01e11d0dcd64609fe6ffd1',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200310,
#   'state': 'CA',
#   'positive': 133,
#   'negative': 690,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '',
#   'dateModified': None,
#   'checkTimeEt': None,
#   'death': None,
#   'hospitalized': None,
#   'dateChecked': None,
#   'totalTestsViral': 823,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 19,
#   'negativeIncrease': 0,
#   'total': 823,
#   'totalTestResults': 823,
#   'totalTestResultsIncrease': 19,
#   'posNeg': 823,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': 'da904a74d1db240d3a1f9fac98823f4064654065',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200309,
#   'state': 'CA',
#   'positive': 114,
#   'negative': 690,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '',
#   'dateModified': None,
#   'checkTimeEt': None,
#   'death': None,
#   'hospitalized': None,
#   'dateChecked': None,
#   'totalTestsViral': 804,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 26,
#   'negativeIncrease': 228,
#   'total': 804,
#   'totalTestResults': 804,
#   'totalTestResultsIncrease': 254,
#   'posNeg': 804,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': '492483138c998beb9a324c26f152f8daa6fa891f',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200308,
#   'state': 'CA',
#   'positive': 88,
#   'negative': 462,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '',
#   'dateModified': None,
#   'checkTimeEt': None,
#   'death': None,
#   'hospitalized': None,
#   'dateChecked': None,
#   'totalTestsViral': 550,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 19,
#   'negativeIncrease': 0,
#   'total': 550,
#   'totalTestResults': 550,
#   'totalTestResultsIncrease': 19,
#   'posNeg': 550,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': '841788a5ae11d1cb868b7d1a0b5dafbc665ba169',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200307,
#   'state': 'CA',
#   'positive': 69,
#   'negative': 462,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '',
#   'dateModified': None,
#   'checkTimeEt': None,
#   'death': None,
#   'hospitalized': None,
#   'dateChecked': None,
#   'totalTestsViral': 531,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 9,
#   'negativeIncrease': 0,
#   'total': 531,
#   'totalTestResults': 531,
#   'totalTestResultsIncrease': 9,
#   'posNeg': 531,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': '97d60a21e9065f4c8044c990091051b3f0c5a49c',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200306,
#   'state': 'CA',
#   'positive': 60,
#   'negative': 462,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '',
#   'dateModified': None,
#   'checkTimeEt': None,
#   'death': None,
#   'hospitalized': None,
#   'dateChecked': None,
#   'totalTestsViral': 522,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 7,
#   'negativeIncrease': 0,
#   'total': 522,
#   'totalTestResults': 522,
#   'totalTestResultsIncrease': 7,
#   'posNeg': 522,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': '662f66bd8d1c194ce87d7404753a9b83515d2695',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200305,
#   'state': 'CA',
#   'positive': 53,
#   'negative': 462,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '',
#   'dateModified': None,
#   'checkTimeEt': None,
#   'death': None,
#   'hospitalized': None,
#   'dateChecked': None,
#   'totalTestsViral': 515,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 0,
#   'negativeIncrease': 0,
#   'total': 515,
#   'totalTestResults': 515,
#   'totalTestResultsIncrease': 0,
#   'posNeg': 515,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': '8ee918675d3f2f0f6b94dee19267e2be366999ff',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200304,
#   'state': 'CA',
#   'positive': 53,
#   'negative': 462,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': '',
#   'lastUpdateEt': '',
#   'dateModified': None,
#   'checkTimeEt': None,
#   'death': None,
#   'hospitalized': None,
#   'dateChecked': None,
#   'totalTestsViral': 515,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 0,
#   'negativeIncrease': 0,
#   'total': 515,
#   'totalTestResults': 515,
#   'totalTestResultsIncrease': 0,
#   'posNeg': 515,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': '5a4090a5d0f48c63008d34430a1845a383bebc1f',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''}]

# %%
# Out:
# [20200806, 20200805, 20200804, 20200803, 20200802, 20200801, 20200731, 20200730, 20200729, 20200728, 20200727, 20200726, 20200725, 20200724, 20200723, 20200722, 20200721, 20200720, 20200719, 20200718, 20200717, 20200716, 20200715, 20200714, 20200713, 20200712, 20200711, 20200710, 20200709, 20200708, 20200707, 20200706, 20200705, 20200704, 20200703, 20200702, 20200701, 20200630, 20200629, 20200628, 20200627, 20200626, 20200625, 20200624, 20200623, 20200622, 20200621, 20200620, 20200619, 20200618, 20200617, 20200616, 20200615, 20200614, 20200613, 20200612, 20200611, 20200610, 20200609, 20200608, 20200607, 20200606, 20200605, 20200604, 20200603, 20200602, 20200601, 20200531, 20200530, 20200529, 20200528, 20200527, 20200526, 20200525, 20200524, 20200523, 20200522, 20200521, 20200520, 20200519, 20200518, 20200517, 20200516, 20200515, 20200514, 20200513, 20200512, 20200511, 20200510, 20200509, 20200508, 20200507, 20200506, 20200505, 20200504, 20200503, 20200502, 20200501, 20200430, 20200429, 20200428, 20200427, 20200426, 20200425, 20200424, 20200423, 20200422, 20200421, 20200420, 20200419, 20200418, 20200417, 20200416, 20200415, 20200414, 20200413, 20200412, 20200411, 20200410, 20200409, 20200408, 20200407, 20200406, 20200405, 20200404, 20200403, 20200402, 20200401, 20200331, 20200330, 20200329, 20200328, 20200327, 20200326, 20200325, 20200324, 20200323, 20200322, 20200321, 20200320, 20200319, 20200318, 20200317, 20200316, 20200315, 20200314, 20200313, 20200312, 20200311, 20200310, 20200309, 20200308, 20200307, 20200306, 20200305, 20200304]

# %% [markdown]
# # 3. Create a list of the fields available for each date in this dataset and label this list 'list_fields'.
# Assume that the fields do not change over time, so you can create this list from any date.

# %%
# Out:
# ['date',
#  'state',
#  'positive',
#  'negative',
#  'pending',
#  'hospitalizedCurrently',
#  'hospitalizedCumulative',
#  'inIcuCurrently',
#  'inIcuCumulative',
#  'onVentilatorCurrently',
#  'onVentilatorCumulative',
#  'recovered',
#  'dataQualityGrade',
#  'lastUpdateEt',
#  'dateModified',
#  'checkTimeEt',
#  'death',
#  'hospitalized',
#  'dateChecked',
#  'totalTestsViral',
#  'positiveTestsViral',
#  'negativeTestsViral',
#  'positiveCasesViral',
#  'deathConfirmed',
#  'deathProbable',
#  'fips',
#  'positiveIncrease',
#  'negativeIncrease',
#  'total',
#  'totalTestResults',
#  'totalTestResultsIncrease',
#  'posNeg',
#  'deathIncrease',
#  'hospitalizedIncrease',
#  'hash',
#  'commercialScore',
#  'negativeRegularScore',
#  'negativeScore',
#  'positiveScore',
#  'score',
#  'grade']

# %%
date_list = []
for x in covid_data:
        date_list.append(x['date'])

# %%
date_list
# Out:
# [20200806,
#  20200805,
#  20200804,
#  20200803,
#  20200802,
#  20200801,
#  20200731,
#  20200730,
#  20200729,
#  20200728,
#  20200727,
#  20200726,
#  20200725,
#  20200724,
#  20200723,
#  20200722,
#  20200721,
#  20200720,
#  20200719,
#  20200718,
#  20200717,
#  20200716,
#  20200715,
#  20200714,
#  20200713,
#  20200712,
#  20200711,
#  20200710,
#  20200709,
#  20200708,
#  20200707,
#  20200706,
#  20200705,
#  20200704,
#  20200703,
#  20200702,
#  20200701,
#  20200630,
#  20200629,
#  20200628,
#  20200627,
#  20200626,
#  20200625,
#  20200624,
#  20200623,
#  20200622,
#  20200621,
#  20200620,
#  20200619,
#  20200618,
#  20200617,
#  20200616,
#  20200615,
#  20200614,
#  20200613,
#  20200612,
#  20200611,
#  20200610,
#  20200609,
#  20200608,
#  20200607,
#  20200606,
#  20200605,
#  20200604,
#  20200603,
#  20200602,
#  20200601,
#  20200531,
#  20200530,
#  20200529,
#  20200528,
#  20200527,
#  20200526,
#  20200525,
#  20200524,
#  20200523,
#  20200522,
#  20200521,
#  20200520,
#  20200519,
#  20200518,
#  20200517,
#  20200516,
#  20200515,
#  20200514,
#  20200513,
#  20200512,
#  20200511,
#  20200510,
#  20200509,
#  20200508,
#  20200507,
#  20200506,
#  20200505,
#  20200504,
#  20200503,
#  20200502,
#  20200501,
#  20200430,
#  20200429,
#  20200428,
#  20200427,
#  20200426,
#  20200425,
#  20200424,
#  20200423,
#  20200422,
#  20200421,
#  20200420,
#  20200419,
#  20200418,
#  20200417,
#  20200416,
#  20200415,
#  20200414,
#  20200413,
#  20200412,
#  20200411,
#  20200410,
#  20200409,
#  20200408,
#  20200407,
#  20200406,
#  20200405,
#  20200404,
#  20200403,
#  20200402,
#  20200401,
#  20200331,
#  20200330,
#  20200329,
#  20200328,
#  20200327,
#  20200326,
#  20200325,
#  20200324,
#  20200323,
#  20200322,
#  20200321,
#  20200320,
#  20200319,
#  20200318,
#  20200317,
#  20200316,
#  20200315,
#  20200314,
#  20200313,
#  20200312,
#  20200311,
#  20200310,
#  20200309,
#  20200308,
#  20200307,
#  20200306,
#  20200305,
#  20200304]

# %% [markdown]
# # 4.On August 6th, 2020, the first date in the list (index zero), find the total number of deaths  and the total new deaths.
#
# What is the percentage increase in deaths on August 6th?

# %%
# Out:
# 9869

# %%
# Out:
# 166

# %%
# Out:
# 0.016820346539669673
